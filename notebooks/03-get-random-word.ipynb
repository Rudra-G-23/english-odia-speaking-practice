# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Rudra\Desktop\english-odia-spelling-practice\data\animals.csv")

# %%
df
# Out:
#     english   odia
# 0       Dog  କୁକୁର
# 1       Cat  ବିଲେଇ
# 2       Cow    ଗାଈ
# 3   Buffalo   ମହିଷ
# 4      Goat   ଛେଳି
# 5     Horse   ଘୋଡା
# 6  Elephant   ହାତୀ
# 7      Lion   ସିଂହ
# 8     Tiger    ବାଘ
# 9    Monkey   ବାନର

# %%
np.random.randint(df.shape[0])
# Out:
# 6

# %%
df.iloc[6]['english']
# Out:
# 'Elephant'

# %%
def get_random(df):
    idx = np.random.randint(df.shape[0])
    english = df.iloc[idx]['english']
    odia = df.iloc[idx]['odia']
    return english, odia

# %%
eng, od = get_random(df)

# %%
eng
# Out:
# 'Cat'

# %%
od
# Out:
# 'ବିଲେଇ'
