# %%
import random

# %%
path = r"C:\Users\Rudra\Desktop\english-odia-speaking-practice\data\only-english-word.txt"

# %%
with open(path, 'r') as f:
    line = f.readline()
    line = line.split(',')
    lien = line.remove('\n')
    print(line)
# Out:
# ['App', 'Goal', 'Happy', 'Rudra', 'Thanks', 'run', 'walk', 'read', 'write']

# %%
len(line)
# Out:
# 9

# %%
random.sample(line, 3)
# Out:
# ['walk', 'Goal', 'write']

# %%
random.randint(a=0, b=len(line))
# Out:
# 5

# %%
line[0: 3]
# Out:
# ['App', 'Goal', 'Happy']

# %%
three_words =  random.sample(line, 3)

# %%
three_words
# Out:
# ['read', 'Rudra', 'walk']

# %%
three_words[1]
# Out:
# 'Rudra'
